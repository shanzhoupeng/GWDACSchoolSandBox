# %% [markdown]
# # Generate the normal distribution and plot it.
# #### Zu-Cheng Chen, Mar 2019
#
# The probability density function (PDF) of the normal distribution is
# $$
#     f(x | \mu, \sigma) = \frac{1}{\sqrt{2\pi\sigma^2}} e^{-\frac{(x-\mu)^2}{2\sigma^2}},
# $$
# where
# * $\mu$ is the `mean` or expectation of the distribution,
# * and $\sigma$ is the `standar deviation (std)`.

# %%
# load packages
using Statistics
using Plots
pyplot();

# %% [markdown]
# ## Define the `randn_plot` function.

# %%
"""
randn_plot(μ, σ, n_sample, bins)
Plot the histogram of random normal distribution 
with the mean μ and width σ.
n_sample is number of samples to be generated and 
n_bin is the number of bins.
"""
function randn_plot(μ = 0, σ = 1, n_sample = 100_000, n_bin = 100)
    samples = μ .+ σ * randn(n_sample)
    println("The mean value is ", mean(samples), " and the std is ", std(samples), ".")
    histogram(samples, 
        bins = n_bin,
        xlabel = "x",
        ylabel = "counts", 
        label = "μ = $μ, σ = $σ",
        title = "Histogram of random normal distribution."
    )
end

# test this function
randn_plot()
# Out:
# The mean value is 0.0018926202144570338 and the std is 1.0004667517696946.

# %% [markdown]
# ## Case 1: $ \mu = 0, \sigma = 1$

# %%
randn_plot(0, 1)
# Out:
# The mean value is -0.0006766673111570802 and the std is 1.0005201665271597.

# %% [markdown]
# ## Case 2: $ \mu = 0, \sigma = 2$

# %%
randn_plot(0, 2)
# Out:
# The mean value is 0.00041076210039361487 and the std is 2.000585477748591.

# %% [markdown]
# ## Case 3: $ \mu = 0, \sigma = \sqrt{2}$

# %%
randn_plot(0, √2)
# Out:
# The mean value is 0.00211839324323319 and the std is 1.4162639918376856.

# %% [markdown]
# ## Case 4: $ \mu = 2, \sigma = \sqrt{2}$

# %%
randn_plot(2, √2)
# Out:
# The mean value is 1.9960158726084558 and the std is 1.4148994756407873.
